# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("laveshjadon/impact-of-ai-on-jobs")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 5.78M/5.78M [00:02<00:00, 2.20MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Adesola Badmos\.cache\kagglehub\datasets\laveshjadon\impact-of-ai-on-jobs\versions\1

# %%
# %pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\Adesola Badmos\AppData\Local\Python\pythoncore-3.12-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path

home = Path.home()
print(home)
# Out:
# C:\Users\Adesola Badmos

# %%
cache = home / ".cache" / "kagglehub"

print(cache)
print(cache.exists())
# Out:
# C:\Users\Adesola Badmos\.cache\kagglehub
# True

# %%
list(cache.rglob("*"))
# Out:
# [WindowsPath('C:/Users/Adesola Badmos/.cache/kagglehub/datasets'),
#  WindowsPath('C:/Users/Adesola Badmos/.cache/kagglehub/datasets/laveshjadon'),
#  WindowsPath('C:/Users/Adesola Badmos/.cache/kagglehub/datasets/laveshjadon/impact-of-ai-on-jobs'),
#  WindowsPath('C:/Users/Adesola Badmos/.cache/kagglehub/datasets/laveshjadon/impact-of-ai-on-jobs/1.complete'),
#  WindowsPath('C:/Users/Adesola Badmos/.cache/kagglehub/datasets/laveshjadon/impact-of-ai-on-jobs/versions'),
#  WindowsPath('C:/Users/Adesola Badmos/.cache/kagglehub/datasets/laveshjadon/impact-of-ai-on-jobs/versions/1'),
#  WindowsPath('C:/Users/Adesola Badmos/.cache/kagglehub/datasets/laveshjadon/impact-of-ai-on-jobs/versions/1/ai_job_impact_dataset.csv')]

# %%
file = cache / "datasets" / "laveshjadhon" / "impact-of-ai-on-jobs" / "versions" / "1" / "ai_job_impact_dataset"

print(file)
print(file.is_file())
# Out:
# C:\Users\Adesola Badmos\.cache\kagglehub\datasets\laveshjadhon\impact-of-ai-on-jobs\versions\1\ai_job_impact_dataset
# False

# %%
matches = list(cache.rglob("ai_job_impact_dataset"))

for item in matches:
    print(item)
    print("Exists:", item.exists())
    print("Is file:", item.is_file())
    print("Is folder:", item.is_dir())

# %%
print(matches)
# Out:
# []

# %%
import pandas as pd

df = pd.read_csv(r"c:\Users\Adesola Badmos\OneDrive\Documents\Project 2\ai_job_impact_dataset.csv")

df.head()
# Out:
#    worker_id     country      continent  year   age  gender education_level  \
# 0          1  Bangladesh           Asia  2035  36.0    Male        Bachelor
# 1          2     Denmark         Europe  2035  58.0    Male        Bachelor
# 2          3     Nigeria         Africa  2035  59.0  Female     High School
# 3          4     Vietnam           Asia  2035  54.0  Female        Bachelor
# 4          5      Mexico  North America  2034  54.0  Female        Bachelor
#
#          industry               job_role  years_experience  ...  \
# 0          Energy         Energy Auditor               7.0  ...
# 1  Transportation      Aviation Mechanic              13.0  ...
# 2              IT        DevOps Engineer              34.0  ...
# 3   Manufacturing  Production Supervisor              21.0  ...
# 4          Retail      Inventory Manager              13.0  ...
#
#    training_hours reskilling_completed automation_probability  \
# ...
