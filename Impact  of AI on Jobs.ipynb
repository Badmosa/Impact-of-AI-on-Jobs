# %%
import pandas as pd

df = pd.read_csv(r"c:\Users\Adesola Badmos\OneDrive\Documents\Project 2\ai_job_impact_dataset.csv")

df.head()
# Out:
#    worker_id     country      continent  year   age  gender education_level  \
# 0          1  Bangladesh           Asia  2035  36.0    Male        Bachelor
# 1          2     Denmark         Europe  2035  58.0    Male        Bachelor
# 2          3     Nigeria         Africa  2035  59.0  Female     High School
# 3          4     Vietnam           Asia  2035  54.0  Female        Bachelor
# 4          5      Mexico  North America  2034  54.0  Female        Bachelor
#
#          industry               job_role  years_experience  ...  \
# 0          Energy         Energy Auditor               7.0  ...
# 1  Transportation      Aviation Mechanic              13.0  ...
# 2              IT        DevOps Engineer              34.0  ...
# 3   Manufacturing  Production Supervisor              21.0  ...
# 4          Retail      Inventory Manager              13.0  ...
#
#    training_hours reskilling_completed automation_probability  \
# 0           136.0                   No                 0.4382
# 1            55.5                  Yes                 0.4848
# 2           110.8                   No                 0.4564
# 3           109.7                  Yes                 0.6871
# 4            71.3                  Yes                 0.3714
#
#   job_satisfaction  promotion_probability  layoff_probability  \
# 0             8.01                 0.5516              0.1362
# 1             8.00                 0.4824              0.2122
# 2             6.11                 0.3561              0.1431
# 3             5.64                 0.3547              0.2724
# 4             9.68                 0.4796              0.1333
#
#    employment_status_after_ai  annual_performance_rating  mental_stress_score  \
# 0                    Employed                       4.16                23.29
# 1                    Employed                       3.65                19.45
# 2                    Employed                       3.42                47.87
# 3                    Employed                       3.77                38.92
# 4                    Employed                       3.79                27.33
#
#    innovation_score
# 0             46.19
# 1             59.25
# 2             16.69
# 3             39.84
# 4             47.53
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#        worker_id country      continent  year   age  gender education_level  \
# 99995      99996  France         Europe  2022  27.0    Male        Bachelor
# 99996      99997   Japan           Asia  2027  57.0    Male          Master
# 99997      99998   India           Asia  2027  23.0  Female     High School
# 99998      99999  Brazil  South America  2024  35.0    Male         Diploma
# 99999     100000   Kenya         Africa  2032  20.0  Female        Bachelor
#
#             industry               job_role  years_experience  ...  \
# 99995          Media             Journalist               5.0  ...
# 99996  Manufacturing    Robotics Technician              13.0  ...
# 99997    Hospitality           Travel Agent               NaN  ...
# 99998          Media   Social Media Manager               8.0  ...
# 99999         Energy  Energy Policy Analyst               0.0  ...
#
#        training_hours reskilling_completed automation_probability  \
# 99995           101.1                  Yes                    NaN
# 99996            63.9                   No                 0.6149
# 99997            72.2                  Yes                 0.3016
# 99998            48.3                   No                 0.2649
# 99999           105.1                   No                 0.3686
#
#       job_satisfaction  promotion_probability  layoff_probability  \
# 99995             7.45                 0.4649              0.0000
# 99996             7.79                 0.5786              0.4566
# 99997             6.55                 0.1554              0.2086
# 99998             7.62                 0.4450              0.1198
# 99999             7.54                 0.4471              0.1147
#
#        employment_status_after_ai  annual_performance_rating  \
# 99995                    Employed                       4.03
# 99996               Career Change                       4.09
# 99997                    Employed                       1.31
# 99998                    Employed                       2.76
# 99999                   Reskilled                       3.54
#
#        mental_stress_score  innovation_score
# 99995                32.94             63.05
# 99996                47.22             54.24
# 99997                25.87              0.00
# 99998                42.57             59.79
# 99999                30.64             50.65
#
# [5 rows x 29 columns]

# %% [markdown]
# # Data Inspection

# %%
# Inspecting all data columns

df.columns.tolist()
# Out:
# ['worker_id',
#  'country',
#  'continent',
#  'year',
#  'age',
#  'gender',
#  'education_level',
#  'industry',
#  'job_role',
#  'years_experience',
#  'salary_usd',
#  'employment_type',
#  'company_size',
#  'remote_work',
#  'ai_adoption_level',
#  'ai_literacy_score',
#  'digital_skill_score',
#  'productivity_score',
#  'hours_worked_per_week',
#  'training_hours',
#  'reskilling_completed',
#  'automation_probability',
#  'job_satisfaction',
#  'promotion_probability',
#  'layoff_probability',
#  'employment_status_after_ai',
#  'annual_performance_rating',
#  'mental_stress_score',
#  'innovation_score']

# %%
# countries and their value check

df['country'].value_counts()
# Out:
# country
# India             6437
# USA               6386
# China             5397
# Indonesia         3231
# UK                3163
# France            2776
# Germany           2753
# Nigeria           2739
# Philippines       2727
# Canada            2700
# Japan             2683
# South Korea       2313
# Brazil            2276
# Vietnam           2273
# Egypt             2260
# South Africa      2243
# Italy             2237
# Saudi Arabia      1856
# Thailand          1839
# Kenya             1832
# UAE               1828
# Netherlands       1822
# Malaysia          1809
# Argentina         1800
# Turkey            1794
# Mexico            1780
# Australia         1779
# Israel            1750
# Spain             1750
# Ghana             1436
# Singapore         1428
# Chile             1420
# Bangladesh        1406
# Switzerland       1406
# Pakistan          1357
# Morocco           1355
# Colombia          1325
# Sweden            1297
# Poland             936
# Greece             936
# New Zealand        930
# Finland            930
# Ireland            926
# Denmark            916
# Peru               910
# Austria            908
# Norway             866
# Belgium            864
# Portugal           858
# Hungary            479
# Romania            459
# Czech Republic     419
# Name: count, dtype: int64

# %%
# A distinct count of all countries
df["country"].nunique()
# Out:
# 52

# %%
df.nunique()
# Out:
# worker_id                     99501
# country                          52
# continent                         6
# year                             16
# age                              48
# gender                            3
# education_level                   5
# industry                         15
# job_role                        298
# years_experience                 47
# salary_usd                    96935
# employment_type                   4
# company_size                      4
# remote_work                       2
# ai_adoption_level              8471
# ai_literacy_score              9494
# digital_skill_score            8570
# productivity_score             8459
# hours_worked_per_week           542
# training_hours                 1683
# reskilling_completed              2
# automation_probability         6912
# job_satisfaction                709
# promotion_probability          5708
# layoff_probability             4642
# employment_status_after_ai        4
# annual_performance_rating       401
# mental_stress_score            5531
# innovation_score               9589
# dtype: int64

# %%
print(df["age"].max())
# Out:
# 65.0

# %%
print(df["age"].min())
# Out:
# 18.0

# %%
print(df["age"].mean())
# Out:
# 41.450654772233165

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# worker_id                        0
# country                          0
# continent                     2092
# year                             0
# age                           2027
# gender                        2004
# education_level               2001
# industry                      1994
# job_role                      2051
# years_experience              2023
# salary_usd                    2035
# employment_type               2017
# company_size                  1988
# remote_work                   1926
# ai_adoption_level             2002
# ai_literacy_score             2011
# digital_skill_score           1894
# productivity_score            2035
# hours_worked_per_week         2036
# training_hours                1932
# reskilling_completed          2029
# automation_probability        1958
# job_satisfaction              1948
# promotion_probability         1975
# layoff_probability            1964
# employment_status_after_ai    2007
# annual_performance_rating     1941
# mental_stress_score           2010
# innovation_score              2001
# dtype: int64

# %%
# Checking for duplicate values

print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 499

# %%
duplicates = df[df.duplicated()].head()

duplicates
# Out:
#       worker_id country      continent  year   age  gender education_level  \
# 1364        633     USA  North America  2020  42.0  Female         Diploma
# 1998        232  Greece         Europe  2034  41.0  Female     High School
# 6138       6139    Peru  South America  2025  51.0    Male        Bachelor
# 6462         44   Spain         Europe  2024  36.0    Male             PhD
# 6546       6547     USA  North America  2024  18.0  Female             PhD
#
#           industry            job_role  years_experience  ...  training_hours  \
# 1364     Education             Teacher              12.0  ...            30.0
# 1998         Media              Editor               9.0  ...           108.8
# 6138    Government  Regulatory Officer              13.0  ...           117.6
# 6462  Construction      Crane Operator               3.0  ...            75.5
# 6546         Legal          Prosecutor               0.0  ...            82.9
#
#      reskilling_completed automation_probability job_satisfaction  \
# 1364                   No                 0.1437             6.01
# 1998                  Yes                 0.5919             9.03
# 6138                   No                 0.3293             7.28
# 6462                   No                 0.4164             8.98
# 6546                  Yes                 0.2335             8.31
#
#       promotion_probability  layoff_probability  employment_status_after_ai  \
# 1364                 0.4678              0.1486                    Employed
# 1998                 0.4879              0.0429                    Employed
# 6138                 0.5083              0.0074                    Employed
# 6462                 0.6003              0.2833                    Employed
# 6546                 0.5345              0.0000                    Employed
#
#       annual_performance_rating  mental_stress_score  innovation_score
# 1364                       3.88                26.79             47.35
# 1998                       3.27                17.92             69.92
# 6138                       3.61                11.56             33.97
# 6462                       3.62                18.93             62.70
# 6546                       2.86                 9.91             71.18
#
# [5 rows x 29 columns]

# %%
print(df.duplicated().sum())
# Out:
# 499

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# # Aanalysis: Who benefits more from AI through its adoption?

# %% [markdown]
# checking if AI adoption is associated with better outcomes using the following columns :
#
# 1. ai_adoption_level
# 2. productivity_score
# 3. salary_usd
# 4. annual_performance_rating
# 5. promotion_probability
# 5. job_satisfaction

# %%
df["ai_adoption_level"].value_counts()
# Out:
# ai_adoption_level
# 100.00    13940
# 72.05        29
# 72.93        29
# 86.63        28
# 58.34        27
#           ...
# 18.13         1
# 20.69         1
# 32.05         1
# 30.73         1
# 16.74         1
# Name: count, Length: 8471, dtype: int64

# %%
df["ai_adoption_level"].unique()
df
# Out:
#        worker_id     country      continent  year   age  gender  \
# 0              1  Bangladesh           Asia  2035  36.0    Male
# 1              2     Denmark         Europe  2035  58.0    Male
# 2              3     Nigeria         Africa  2035  59.0  Female
# 3              4     Vietnam           Asia  2035  54.0  Female
# 4              5      Mexico  North America  2034  54.0  Female
# ...          ...         ...            ...   ...   ...     ...
# 99995      99996      France         Europe  2022  27.0    Male
# 99996      99997       Japan           Asia  2027  57.0    Male
# 99997      99998       India           Asia  2027  23.0  Female
# 99998      99999      Brazil  South America  2024  35.0    Male
# 99999     100000       Kenya         Africa  2032  20.0  Female
#
#       education_level        industry               job_role  \
# 0            Bachelor          Energy         Energy Auditor
# 1            Bachelor  Transportation      Aviation Mechanic
# 2         High School              IT        DevOps Engineer
# 3            Bachelor   Manufacturing  Production Supervisor
# 4            Bachelor          Retail      Inventory Manager
# ...               ...             ...                    ...
# 99995        Bachelor           Media             Journalist
# 99996          Master   Manufacturing    Robotics Technician
# 99997     High School     Hospitality           Travel Agent
# 99998         Diploma           Media   Social Media Manager
# 99999        Bachelor          Energy  Energy Policy Analyst
#
#        years_experience  ...  training_hours reskilling_completed  \
# 0                   7.0  ...           136.0                   No
# 1                  13.0  ...            55.5                  Yes
# 2                  34.0  ...           110.8                   No
# 3                  21.0  ...           109.7                  Yes
# 4                  13.0  ...            71.3                  Yes
# ...                 ...  ...             ...                  ...
# 99995               5.0  ...           101.1                  Yes
# 99996              13.0  ...            63.9                   No
# 99997               NaN  ...            72.2                  Yes
# 99998               8.0  ...            48.3                   No
# 99999               0.0  ...           105.1                   No
#
#       automation_probability job_satisfaction  promotion_probability  \
# 0                     0.4382             8.01                 0.5516
# 1                     0.4848             8.00                 0.4824
# 2                     0.4564             6.11                 0.3561
# 3                     0.6871             5.64                 0.3547
# 4                     0.3714             9.68                 0.4796
# ...                      ...              ...                    ...
# 99995                    NaN             7.45                 0.4649
# 99996                 0.6149             7.79                 0.5786
# 99997                 0.3016             6.55                 0.1554
# 99998                 0.2649             7.62                 0.4450
# 99999                 0.3686             7.54                 0.4471
#
#        layoff_probability  employment_status_after_ai  \
# 0                  0.1362                    Employed
# 1                  0.2122                    Employed
# 2                  0.1431                    Employed
# 3                  0.2724                    Employed
# 4                  0.1333                    Employed
# ...                   ...                         ...
# 99995              0.0000                    Employed
# 99996              0.4566               Career Change
# 99997              0.2086                    Employed
# 99998              0.1198                    Employed
# 99999              0.1147                   Reskilled
#
#        annual_performance_rating  mental_stress_score  innovation_score
# 0                           4.16                23.29             46.19
# 1                           3.65                19.45             59.25
# 2                           3.42                47.87             16.69
# 3                           3.77                38.92             39.84
# 4                           3.79                27.33             47.53
# ...                          ...                  ...               ...
# 99995                       4.03                32.94             63.05
# 99996                       4.09                47.22             54.24
# 99997                       1.31                25.87              0.00
# 99998                       2.76                42.57             59.79
# 99999                       3.54                30.64             50.65
#
# [100000 rows x 29 columns]

# %%
# comparing outcome by ai_aduption_level

df.groupby("ai_adoption_level")[[
    "productivity_score",
    "salary_usd",
    "promotion_probability",
    "job_satisfaction"
]].mean()
# Out:
#                    productivity_score     salary_usd  promotion_probability  \
# ai_adoption_level
# 0.00                        43.246154   28410.688462               0.376077
# 0.83                        59.920000   16460.780000               0.454600
# 0.99                        34.860000    2826.220000               0.333200
# 1.04                        32.980000   49123.710000                    NaN
# 1.15                        44.640000   12709.220000               0.342600
# ...                               ...            ...                    ...
# 99.96                       56.954167   41416.905714               0.450614
# 99.97                       63.256250   91997.611875               0.487181
# 99.98                       54.395556   83194.372222               0.413389
# 99.99                       59.156000  107777.580000               0.454840
# 100.00                      58.918064   90928.495640               0.472938
#
#                    job_satisfaction
# ai_adoption_level
# 0.00                       6.644615
# 0.83                       4.880000
# 0.99                       6.760000
# 1.04                       7.470000
# 1.15                       6.910000
# ...                             ...
# 99.96                      7.751818
# 99.97                      7.502500
# 99.98                      7.023333
# 99.99                      7.747500
# 100.00                     7.391671
#
# [8471 rows x 4 columns]

# %%
# checking the missing values

df[[
    "ai_adoption_level",
    "productivity_score",
    "salary_usd",
    "promotion_probability",
    "job_satisfaction"
]].isna().sum()
# Out:
# ai_adoption_level        2002
# productivity_score       2035
# salary_usd               2035
# promotion_probability    1975
# job_satisfaction         1948
# dtype: int64

# %%
# average impact of ai on jobs.

ai_impact = df.groupby("ai_adoption_level")[[
    "productivity_score",
    "salary_usd",
    "promotion_probability",
    "job_satisfaction"
]].mean()

ai_impact
# Out:
#                    productivity_score     salary_usd  promotion_probability  \
# ai_adoption_level
# 0.00                        43.246154   28410.688462               0.376077
# 0.83                        59.920000   16460.780000               0.454600
# 0.99                        34.860000    2826.220000               0.333200
# 1.04                        32.980000   49123.710000                    NaN
# 1.15                        44.640000   12709.220000               0.342600
# ...                               ...            ...                    ...
# 99.96                       56.954167   41416.905714               0.450614
# 99.97                       63.256250   91997.611875               0.487181
# 99.98                       54.395556   83194.372222               0.413389
# 99.99                       59.156000  107777.580000               0.454840
# 100.00                      58.918064   90928.495640               0.472938
#
#                    job_satisfaction
# ai_adoption_level
# 0.00                       6.644615
# 0.83                       4.880000
# 0.99                       6.760000
# 1.04                       7.470000
# 1.15                       6.910000
# ...                             ...
# 99.96                      7.751818
# 99.97                      7.502500
# 99.98                      7.023333
# 99.99                      7.747500
# 100.00                     7.391671
#
# [8471 rows x 4 columns]

# %%
# grouping impact to see status

df["ai_adoption_group"] = pd.cut(
    df["ai_adoption_level"],
    bins=[0, 25, 50, 75, 100],
    labels=["Low", "Medium", "High", "Very High"],
    include_lowest=True
)

# the actual grouping status
df["ai_adoption_group"].value_counts().sort_index()
# Out:
# ai_adoption_group
# Low           1657
# Medium       14697
# High         35516
# Very High    46128
# Name: count, dtype: int64

# %%
df["ai_adoption_group"].value_counts().sort_index()
# Out:
# ai_adoption_group
# Low           1657
# Medium       14697
# High         35516
# Very High    46128
# Name: count, dtype: int64

# %%
ai_impact = df.groupby("ai_adoption_group", observed=True)[[
    "productivity_score",
    "salary_usd",
    "promotion_probability",
    "job_satisfaction"
]].mean()

ai_impact
# Out:
#                    productivity_score    salary_usd  promotion_probability  \
# ai_adoption_group
# Low                         42.244025  25358.219736               0.369006
# Medium                      45.912388  32242.227552               0.387998
# High                        49.936164  43047.250225               0.411011
# Very High                   56.044681  69336.781137               0.452328
#
#                    job_satisfaction
# ai_adoption_group
# Low                        6.813266
# Medium                     6.912538
# High                       7.034317
# Very High                  7.251106

# %%
print(ai_impact.to_string())
# Out:
#                    productivity_score    salary_usd  promotion_probability  job_satisfaction
# ai_adoption_group
# Low                         42.244025  25358.219736               0.369006          6.813266
# Medium                      45.912388  32242.227552               0.387998          6.912538
# High                        49.936164  43047.250225               0.411011          7.034317
# Very High                   56.044681  69336.781137               0.452328          7.251106

# %% [markdown]
# Key things to note here:
#
# 1. Productivity rises from Low to Very High: 42.24 to 56.04
# That's about a 32.7% increase.
#
# 2. Salary rises dramatically from: $25,358 to $69,337
# That's about a 173% increase.
#
# 3. Promotion probability rises from 36.9% to 45.2%
# That's an increase of about 8.3 percentage points.
#
# 4. Job satisfaction also rises from 6.81 to 7.25
# That is a smaller increase, but still upward.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ai_impact["productivity_score"].plot(kind="bar")

plt.title("AI Adoption vs Productivity")
plt.xlabel(" ")
plt.ylabel(" ")
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    x=ai_impact.index,
    y=ai_impact["salary_usd"]
)

plt.title("AI Adoption vs Salary", fontsize=16)
plt.xlabel(" ")
plt.ylabel(" ")
plt.xticks(rotation=0)
plt.ticklabel_format(style="plain", axis="y")
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as mtick

plt.figure(figsize=(9, 5))

sns.barplot(
    x=ai_impact.index,
    y=ai_impact["promotion_probability"]
)

plt.title("AI Adoption vs Promotion Probability", fontsize=16)
plt.xlabel(" ")
plt.ylabel(" ")
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    x=ai_impact.index,
    y=ai_impact["job_satisfaction"]
)

plt.title("AI Adoption vs Job Satisfaction", fontsize=16)
plt.xlabel("AI Adoption Level")
plt.ylabel("Average Job Satisfaction")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis 2: Who is at risk from AI?

# %% [markdown]
# To identify who is at at ai risk, I identify the workers, industries, and job roles that are most exposed to AI-driven displacement using the following columns from the dataset:
#
# 1. automation_probability
# 2. layoff_probability
# 3. employment_status_after_ai
# 4. industry
# 5. job_role

# %%
# using "groupby" to check average automation and layoff probabilities to check if worker risk increase or decrease as AI adoption increases

risk_by_ai = df.groupby("ai_adoption_group", observed=True)[[
    "automation_probability",
    "layoff_probability"
]].mean()

risk_by_ai
# Out:
#                    automation_probability  layoff_probability
# ai_adoption_group
# Low                              0.327978            0.175876
# Medium                           0.322413            0.149225
# High                             0.346542            0.138561
# Very High                        0.403681            0.122490

# %%
# Rounding "risk_by_ai" output for better view and understanding.

risk_by_ai_percentage = (risk_by_ai * 100).round(1)

risk_by_ai_percentage
# Out:
#                    automation_probability  layoff_probability
# ai_adoption_group
# Low                                  32.8                17.6
# Medium                               32.2                14.9
# High                                 34.7                13.9
# Very High                            40.4                12.2

# %%
df["employment_status_after_ai"].value_counts()
# Out:
# employment_status_after_ai
# Employed         85571
# Reskilled         7430
# Career Change     3685
# Unemployed        1307
# Name: count, dtype: int64

# %%
df["employment_status_after_ai"].value_counts(normalize=True) * 100
# Out:
# employment_status_after_ai
# Employed         87.323584
# Reskilled         7.582174
# Career Change     3.760473
# Unemployed        1.333769
# Name: proportion, dtype: float64

# %%
# Find the most vulnerable job roles


risk_by_role = df.groupby("job_role")[[
    "automation_probability",
    "layoff_probability"
]].mean().sort_values(
    "automation_probability",
    ascending=False
)

risk_by_role.head(5)
# Out:
#                         automation_probability  layoff_probability
# job_role
# Fabrication Specialist                0.584594            0.244267
# Industrial Engineer                   0.583264            0.228246
# Assembly Line Worker                  0.581263            0.223808
# Machine Operator                      0.581200            0.238739
# Maintenance Technician                0.579946            0.234820

# %%
risk_by_role_percentage = (risk_by_role * 100).round(1)

risk_by_role_percentage
# Out:
#                         automation_probability  layoff_probability
# job_role
# Fabrication Specialist                    58.5                24.4
# Industrial Engineer                       58.3                22.8
# Assembly Line Worker                      58.1                22.4
# Machine Operator                          58.1                23.9
# Maintenance Technician                    58.0                23.5
# ...                                        ...                 ...
# Clinical Researcher                       22.7                 9.6
# Psychiatrist                              22.7                 8.6
# Pharmacist                                22.6                 9.7
# Hospital Manager                          22.6                 8.3
# Medical Lab Technician                    22.6                 8.6
#
# [298 rows x 2 columns]

# %%
risk_by_role_percentage.head(10).style.format("{:.1f}%")
# Out:
# <style type="text/css">
# </style>
# <table id="T_44de0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44de0_level0_col0" class="col_heading level0 col0" >automation_probability</th>
#       <th id="T_44de0_level0_col1" class="col_heading level0 col1" >layoff_probability</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >job_role</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44de0_level0_row0" class="row_heading level0 row0" >Fabrication Specialist</th>
#       <td id="T_44de0_row0_col0" class="data row0 col0" >58.5%</td>
#       <td id="T_44de0_row0_col1" class="data row0 col1" >24.4%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row1" class="row_heading level0 row1" >Industrial Engineer</th>
#       <td id="T_44de0_row1_col0" class="data row1 col0" >58.3%</td>
#       <td id="T_44de0_row1_col1" class="data row1 col1" >22.8%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row2" class="row_heading level0 row2" >Assembly Line Worker</th>
#       <td id="T_44de0_row2_col0" class="data row2 col0" >58.1%</td>
#       <td id="T_44de0_row2_col1" class="data row2 col1" >22.4%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row3" class="row_heading level0 row3" >Machine Operator</th>
#       <td id="T_44de0_row3_col0" class="data row3 col0" >58.1%</td>
#       <td id="T_44de0_row3_col1" class="data row3 col1" >23.9%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row4" class="row_heading level0 row4" >Maintenance Technician</th>
#       <td id="T_44de0_row4_col0" class="data row4 col0" >58.0%</td>
#       <td id="T_44de0_row4_col1" class="data row4 col1" >23.5%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row5" class="row_heading level0 row5" >Manufacturing Technician</th>
#       <td id="T_44de0_row5_col0" class="data row5 col0" >57.9%</td>
#       <td id="T_44de0_row5_col1" class="data row5 col1" >23.6%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row6" class="row_heading level0 row6" >Tool and Die Maker</th>
#       <td id="T_44de0_row6_col0" class="data row6 col0" >57.9%</td>
#       <td id="T_44de0_row6_col1" class="data row6 col1" >22.1%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row7" class="row_heading level0 row7" >Supply Chain Coordinator</th>
#       <td id="T_44de0_row7_col0" class="data row7 col0" >57.8%</td>
#       <td id="T_44de0_row7_col1" class="data row7 col1" >23.5%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row8" class="row_heading level0 row8" >Production Supervisor</th>
#       <td id="T_44de0_row8_col0" class="data row8 col0" >57.8%</td>
#       <td id="T_44de0_row8_col1" class="data row8 col1" >23.4%</td>
#     </tr>
#     <tr>
#       <th id="T_44de0_level0_row9" class="row_heading level0 row9" >Quality Assurance Manager</th>
#       <td id="T_44de0_row9_col0" class="data row9 col0" >57.6%</td>
#       <td id="T_44de0_row9_col1" class="data row9 col1" >22.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Final Top 5 highest ranking job roles

top_risk = risk_by_role.sort_values(
    "automation_probability",
    ascending=False
).head()

top_risk_percentage = (top_risk * 100).round(1)

top_risk_percentage
# Out:
#                         automation_probability  layoff_probability
# job_role
# Fabrication Specialist                    58.5                24.4
# Industrial Engineer                       58.3                22.8
# Assembly Line Worker                      58.1                22.4
# Machine Operator                          58.1                23.9
# Maintenance Technician                    58.0                23.5

# %%
# chart

plt.figure(figsize=(10, 6))

sns.barplot(
    data=top_risk_percentage.reset_index(),
    x="automation_probability",
    y="job_role"
)

plt.title("Top Jobs by AI Automation Risk")
plt.xlabel(" ")
plt.ylabel(" ")

plt.tight_layout()
plt.show()

# %%
# Finding overall risk

import numpy as np

risk_by_role["overall_risk"] = np.mean(
    [
        risk_by_role["automation_probability"],
        risk_by_role["layoff_probability"]
    ],
    axis=0
)

# %%
# Overall ai job risk

Overall_ai_job_risk = risk_by_role.sort_values(
    "overall_risk",
    ascending=False
).head(10)

print(Overall_ai_job_risk)
# Out:
#                           automation_probability  layoff_probability  \
# job_role
# Fabrication Specialist                  0.584594            0.244267
# Machine Operator                        0.581200            0.238739
# Manufacturing Technician                0.579251            0.236243
# Maintenance Technician                  0.579946            0.234820
# Production Planner                      0.574892            0.239286
# Supply Chain Coordinator                0.578320            0.235143
# Logistics Coordinator                   0.575406            0.237496
# Production Supervisor                   0.578261            0.233736
# Industrial Engineer                     0.583264            0.228246
# Packaging Operator                      0.574720            0.234321
#
#                           overall_risk
# job_role
# Fabrication Specialist        0.414430
# Machine Operator              0.409969
# Manufacturing Technician      0.407747
# Maintenance Technician        0.407383
# Production Planner            0.407089
# Supply Chain Coordinator      0.406731
# Logistics Coordinator         0.406451
# Production Supervisor         0.405998
# Industrial Engineer           0.405755
# Packaging Operator            0.404520

# %%
# Overall risk formatting

Overall_ai_job_risk.style.format("{:.1f}%")
# Out:
# <style type="text/css">
# </style>
# <table id="T_65a34">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65a34_level0_col0" class="col_heading level0 col0" >automation_probability</th>
#       <th id="T_65a34_level0_col1" class="col_heading level0 col1" >layoff_probability</th>
#       <th id="T_65a34_level0_col2" class="col_heading level0 col2" >overall_risk</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >job_role</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65a34_level0_row0" class="row_heading level0 row0" >Fabrication Specialist</th>
#       <td id="T_65a34_row0_col0" class="data row0 col0" >0.6%</td>
#       <td id="T_65a34_row0_col1" class="data row0 col1" >0.2%</td>
#       <td id="T_65a34_row0_col2" class="data row0 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row1" class="row_heading level0 row1" >Machine Operator</th>
#       <td id="T_65a34_row1_col0" class="data row1 col0" >0.6%</td>
#       <td id="T_65a34_row1_col1" class="data row1 col1" >0.2%</td>
#       <td id="T_65a34_row1_col2" class="data row1 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row2" class="row_heading level0 row2" >Manufacturing Technician</th>
#       <td id="T_65a34_row2_col0" class="data row2 col0" >0.6%</td>
#       <td id="T_65a34_row2_col1" class="data row2 col1" >0.2%</td>
#       <td id="T_65a34_row2_col2" class="data row2 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row3" class="row_heading level0 row3" >Maintenance Technician</th>
#       <td id="T_65a34_row3_col0" class="data row3 col0" >0.6%</td>
#       <td id="T_65a34_row3_col1" class="data row3 col1" >0.2%</td>
#       <td id="T_65a34_row3_col2" class="data row3 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row4" class="row_heading level0 row4" >Production Planner</th>
#       <td id="T_65a34_row4_col0" class="data row4 col0" >0.6%</td>
#       <td id="T_65a34_row4_col1" class="data row4 col1" >0.2%</td>
#       <td id="T_65a34_row4_col2" class="data row4 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row5" class="row_heading level0 row5" >Supply Chain Coordinator</th>
#       <td id="T_65a34_row5_col0" class="data row5 col0" >0.6%</td>
#       <td id="T_65a34_row5_col1" class="data row5 col1" >0.2%</td>
#       <td id="T_65a34_row5_col2" class="data row5 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row6" class="row_heading level0 row6" >Logistics Coordinator</th>
#       <td id="T_65a34_row6_col0" class="data row6 col0" >0.6%</td>
#       <td id="T_65a34_row6_col1" class="data row6 col1" >0.2%</td>
#       <td id="T_65a34_row6_col2" class="data row6 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row7" class="row_heading level0 row7" >Production Supervisor</th>
#       <td id="T_65a34_row7_col0" class="data row7 col0" >0.6%</td>
#       <td id="T_65a34_row7_col1" class="data row7 col1" >0.2%</td>
#       <td id="T_65a34_row7_col2" class="data row7 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row8" class="row_heading level0 row8" >Industrial Engineer</th>
#       <td id="T_65a34_row8_col0" class="data row8 col0" >0.6%</td>
#       <td id="T_65a34_row8_col1" class="data row8 col1" >0.2%</td>
#       <td id="T_65a34_row8_col2" class="data row8 col2" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_65a34_level0_row9" class="row_heading level0 row9" >Packaging Operator</th>
#       <td id="T_65a34_row9_col0" class="data row9 col0" >0.6%</td>
#       <td id="T_65a34_row9_col1" class="data row9 col1" >0.2%</td>
#       <td id="T_65a34_row9_col2" class="data row9 col2" >0.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Rounding overall_ai_job_risk value.

Overall_ai_job_risk = (risk_by_role["overall_risk"] * 100).round(1)

# %%
# chart for the jobs at risk frisk from AI

top_5 = Overall_ai_job_risk.sort_values(ascending=False).head()

plt.figure(figsize=(11, 7))

sns.barplot(
    x=top_5.values,
    y=top_5.index
)

plt.title("Top Jobs at Risk from AI")
plt.xlabel(" ")
plt.ylabel(" ")

plt.xlim(0, top_5.max() + 5)

for i, value in enumerate(top_5.values):
    plt.text(
        value + 0.5,
        i,
        f"{value:.1f}%",
        va="center"
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis 3: Does reskilling work?

# %% [markdown]
# Here we'll be testing if workers who completed reskilling have better outcomes after AI and we'll be fpcusing on the following columns from the data set:
#
# 1. reskilling_completed
# 2. training_hours
# 3. employment_status_after_ai
# 4. automation_probability
# 5. layoff_probability
# 6. salary_usd
# 7. promotion_probability

# %%
# value check

df["reskilling_completed"].value_counts()
# Out:
# reskilling_completed
# No     57457
# Yes    40514
# Name: count, dtype: int64

# %%
# comparing the re-skilled and non-reskilled workers

reskill_impact = df.groupby("reskilling_completed")[[
    "training_hours",
    "automation_probability",
    "layoff_probability",
    "salary_usd",
    "promotion_probability"
]].mean()

reskill_impact
# Out:
#                       training_hours  automation_probability  \
# reskilling_completed
# No                         78.345297                0.359937
# Yes                        83.562157                0.383074
#
#                       layoff_probability    salary_usd  promotion_probability
# reskilling_completed
# No                              0.165586  53474.113035               0.426084
# Yes                             0.087221  53492.300925               0.426531

# %%
# more comparism between skilled and non-reskilled workers
pd.crosstab(
    df["reskilling_completed"],
    df["employment_status_after_ai"],
    normalize="index"
) * 100
# Out:
# employment_status_after_ai  Career Change   Employed  Reskilled  Unemployed
# reskilling_completed
# No                               5.230256  84.316337   8.313354    2.140054
# Yes                              1.655079  91.643994   6.537183    0.163744

# %%
reskill_outcomes = pd.crosstab(
    df["reskilling_completed"],
    df["employment_status_after_ai"],
    normalize="index"
) * 100

difference = np.subtract(
    reskill_outcomes.loc["Yes"],
    reskill_outcomes.loc["No"]
)

difference.round(1)
# Out:
# employment_status_after_ai
# Career Change   -3.6
# Employed         7.3
# Reskilled       -1.8
# Unemployed      -2.0
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

employment_outcomes = pd.crosstab(
    df["reskilling_completed"],
    df["employment_status_after_ai"],
    normalize="index"
) * 100

employment_outcomes = employment_outcomes.reset_index()

employment_outcomes = employment_outcomes.melt(
    id_vars="reskilling_completed",
    var_name="employment_status",
    value_name="percentage"
)

plt.figure(figsize=(11, 6))

sns.barplot(
    data=employment_outcomes,
    x="employment_status",
    y="percentage",
    hue="reskilling_completed"
)

plt.title("Employment Outcomes: Reskilled vs Non-Reskilled Workers"
         )

plt.xlabel("Employment Status")
plt.ylabel(" ")
plt.ylim(0, 100)

plt.legend(title="Reskilling Completed")

plt.tight_layout()
plt.show()

# %% [markdown]
# The above chart shows that reskilled workers have a much higher employment rate and dramatically lower unemployment rate.

# %% [markdown]
# # Analysis Question 4: Do workers with higher AI literacy earn more than those with lower AI literacy?

# %%
# Creating an ai literacy group

df["ai_literacy_group"] = pd.cut(
    df["ai_literacy_score"],
    bins=[0, 25, 50, 75, 100],
    labels=["Low", "Medium", "High", "Expert"],
    include_lowest=True
)

df
# Out:
#        worker_id     country      continent  year   age  gender  \
# 0              1  Bangladesh           Asia  2035  36.0    Male
# 1              2     Denmark         Europe  2035  58.0    Male
# 2              3     Nigeria         Africa  2035  59.0  Female
# 3              4     Vietnam           Asia  2035  54.0  Female
# 4              5      Mexico  North America  2034  54.0  Female
# ...          ...         ...            ...   ...   ...     ...
# 99995      99996      France         Europe  2022  27.0    Male
# 99996      99997       Japan           Asia  2027  57.0    Male
# 99997      99998       India           Asia  2027  23.0  Female
# 99998      99999      Brazil  South America  2024  35.0    Male
# 99999     100000       Kenya         Africa  2032  20.0  Female
#
#       education_level        industry               job_role  \
# 0            Bachelor          Energy         Energy Auditor
# 1            Bachelor  Transportation      Aviation Mechanic
# 2         High School              IT        DevOps Engineer
# 3            Bachelor   Manufacturing  Production Supervisor
# 4            Bachelor          Retail      Inventory Manager
# ...               ...             ...                    ...
# 99995        Bachelor           Media             Journalist
# 99996          Master   Manufacturing    Robotics Technician
# 99997     High School     Hospitality           Travel Agent
# 99998         Diploma           Media   Social Media Manager
# 99999        Bachelor          Energy  Energy Policy Analyst
#
#        years_experience  ...  automation_probability job_satisfaction  \
# 0                   7.0  ...                  0.4382             8.01
# 1                  13.0  ...                  0.4848             8.00
# 2                  34.0  ...                  0.4564             6.11
# 3                  21.0  ...                  0.6871             5.64
# 4                  13.0  ...                  0.3714             9.68
# ...                 ...  ...                     ...              ...
# 99995               5.0  ...                     NaN             7.45
# 99996              13.0  ...                  0.6149             7.79
# 99997               NaN  ...                  0.3016             6.55
# 99998               8.0  ...                  0.2649             7.62
# 99999               0.0  ...                  0.3686             7.54
#
#       promotion_probability layoff_probability  employment_status_after_ai  \
# 0                    0.5516             0.1362                    Employed
# 1                    0.4824             0.2122                    Employed
# 2                    0.3561             0.1431                    Employed
# 3                    0.3547             0.2724                    Employed
# 4                    0.4796             0.1333                    Employed
# ...                     ...                ...                         ...
# 99995                0.4649             0.0000                    Employed
# 99996                0.5786             0.4566               Career Change
# 99997                0.1554             0.2086                    Employed
# 99998                0.4450             0.1198                    Employed
# 99999                0.4471             0.1147                   Reskilled
#
#        annual_performance_rating  mental_stress_score  innovation_score  \
# 0                           4.16                23.29             46.19
# 1                           3.65                19.45             59.25
# 2                           3.42                47.87             16.69
# 3                           3.77                38.92             39.84
# 4                           3.79                27.33             47.53
# ...                          ...                  ...               ...
# 99995                       4.03                32.94             63.05
# 99996                       4.09                47.22             54.24
# 99997                       1.31                25.87              0.00
# 99998                       2.76                42.57             59.79
# 99999                       3.54                30.64             50.65
#
#        ai_adoption_group  ai_literacy_group
# 0              Very High               High
# 1              Very High             Medium
# 2              Very High                Low
# 3              Very High             Medium
# 4                   High             Medium
# ...                  ...                ...
# 99995               High               High
# 99996               High               High
# 99997             Medium                Low
# 99998          Very High             Medium
# 99999          Very High               High
#
# [100000 rows x 31 columns]

# %%
# Comparing each of the liteacy gorups

salary_premium = df.groupby("ai_literacy_group", observed=True)[[
    "salary_usd",
    "promotion_probability",
    "digital_skill_score"
]].mean()

salary_premium
# Out:
#                      salary_usd  promotion_probability  digital_skill_score
# ai_literacy_group
# Low                29333.555037               0.341592            14.823654
# Medium             43076.364861               0.403142            30.989190
# High               68645.777077               0.472730            49.851871
# Expert             91842.893398               0.527816            67.220602

# %%
# formating 
salary_premium.style.format({
    "salary_usd": "${:,.0f}",
    "promotion_probability": "{:.1%}",
    "digital_skill_score": "{:.1f}"
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_97ef6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97ef6_level0_col0" class="col_heading level0 col0" >salary_usd</th>
#       <th id="T_97ef6_level0_col1" class="col_heading level0 col1" >promotion_probability</th>
#       <th id="T_97ef6_level0_col2" class="col_heading level0 col2" >digital_skill_score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ai_literacy_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97ef6_level0_row0" class="row_heading level0 row0" >Low</th>
#       <td id="T_97ef6_row0_col0" class="data row0 col0" >$29,334</td>
#       <td id="T_97ef6_row0_col1" class="data row0 col1" >34.2%</td>
#       <td id="T_97ef6_row0_col2" class="data row0 col2" >14.8</td>
#     </tr>
#     <tr>
#       <th id="T_97ef6_level0_row1" class="row_heading level0 row1" >Medium</th>
#       <td id="T_97ef6_row1_col0" class="data row1 col0" >$43,076</td>
#       <td id="T_97ef6_row1_col1" class="data row1 col1" >40.3%</td>
#       <td id="T_97ef6_row1_col2" class="data row1 col2" >31.0</td>
#     </tr>
#     <tr>
#       <th id="T_97ef6_level0_row2" class="row_heading level0 row2" >High</th>
#       <td id="T_97ef6_row2_col0" class="data row2 col0" >$68,646</td>
#       <td id="T_97ef6_row2_col1" class="data row2 col1" >47.3%</td>
#       <td id="T_97ef6_row2_col2" class="data row2 col2" >49.9</td>
#     </tr>
#     <tr>
#       <th id="T_97ef6_level0_row3" class="row_heading level0 row3" >Expert</th>
#       <td id="T_97ef6_row3_col0" class="data row3 col0" >$91,843</td>
#       <td id="T_97ef6_row3_col1" class="data row3 col1" >52.8%</td>
#       <td id="T_97ef6_row3_col2" class="data row3 col2" >67.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
low_salary = salary_premium.loc["Low", "salary_usd"]
expert_salary = salary_premium.loc["Expert", "salary_usd"]

salary_premium_pct = np.divide(
    expert_salary - low_salary,
    low_salary
) * 100

print(f"AI salary premium: {salary_premium_pct:.1f}%")
# Out:
# AI salary premium: 213.1%

# %%
# chart for ai literacy vs average salary

salary_premium = salary_premium.sort_values(
    "salary_usd",
    ascending=False
)

plt.figure(figsize=(10, 6))

sns.barplot(
    data=salary_premium.reset_index(),
    x="ai_literacy_group",
    y="salary_usd",
    order=salary_premium.index
)

plt.title("Average Salary", fontsize=16)
plt.xlabel(" ")
plt.ylabel(" ")

plt.ticklabel_format(style="plain", axis="y")

for i, value in enumerate(salary_premium["salary_usd"]):
    plt.text(
        i,
        value + 2000,
        f"${value:,.0f}",
        ha="center",
        fontweight="bold"
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis Question 5: What is the human cost?

# %% [markdown]
# We want to examine whether higher AI adoption is associated with higher stress and lower job satisfaction

# %%
# Calculate stress and satisfaction by AI adoption group
human_cost = df.groupby("ai_adoption_group", observed=True)[[
    "mental_stress_score",
    "job_satisfaction"
]].mean()

human_cost
# Out:
#                    mental_stress_score  job_satisfaction
# ai_adoption_group
# Low                          30.924009          6.813266
# Medium                       29.758862          6.912538
# High                         29.060976          7.034317
# Very High                    28.058843          7.251106

# %%
# Round the results
human_cost = human_cost.round(1)

human_cost
# Out:
#                    mental_stress_score  job_satisfaction
# ai_adoption_group
# Low                               30.9               6.8
# Medium                            29.8               6.9
# High                              29.1               7.0
# Very High                         28.1               7.3

# %%
# what does it cost to higher humans?

human_cost["human_cost_index"] = (
    human_cost["mental_stress_score"] -
    human_cost["job_satisfaction"]
)

human_cost
# Out:
#                    mental_stress_score  job_satisfaction  human_cost_index
# ai_adoption_group
# Low                               30.9               6.8              24.1
# Medium                            29.8               6.9              22.9
# High                              29.1               7.0              22.1
# Very High                         28.1               7.3              20.8

# %%
# chart for the level of workers "mental stress" compared with "ai adoption".

plt.figure(figsize=(10, 6))

sns.lineplot(
    data=human_cost.reset_index(),
    x="ai_adoption_group",
    y="mental_stress_score",
    marker="o",
    linewidth=2.5,
    label="Mental Stress"
)

plt.title(
    "Level of Mental Stress",
    fontsize=17,
    fontweight="bold"
)

plt.xlabel(" ")
plt.ylabel(" ")

plt.tight_layout()
plt.show()

# %%
# chart for the level of workers "job certisfaction" compared with ai "adoption".

plt.figure(figsize=(10, 6))

sns.lineplot(
    data=human_cost.reset_index(),
    x="ai_adoption_group",
    y="job_satisfaction",
    marker="o",
    linewidth=2.5,
    label="Job Satisfaction"
)

plt.title(
    "Job Satisfaction",
    fontsize=17,
    fontweight="bold"
)

plt.xlabel(" ")
plt.ylabel(" ")

plt.tight_layout()
plt.show()

# %% [markdown]
# Overall, a higher AI adoption was associated with lower mental stress and higher job satisfaction among workers in the dataset. This suggests that AI adoption may improve rather than worsen employee experience, although the analysis shows association, not causation.
